# %% [markdown]
# # 2.1 Analytical Multivariate LSTM Model

# %%
# Import essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from functools import reduce
from pandas import read_csv
from matplotlib import pyplot

# Import LSTM libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# from keras.preprocessing.timeseries import TimeseriesGenerator
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.metrics import mean_squared_error
import tensorflow as tf 
tf.keras.preprocessing.timeseries_dataset_from_array
# Out:
# <function keras.src.utils.timeseries_dataset_utils.timeseries_dataset_from_array(data, targets, sequence_length, sequence_stride=1, sampling_rate=1, batch_size=128, shuffle=False, seed=None, start_index=None, end_index=None)>

# %%
# Import all datasets
oil_data_clean = pd.read_csv('cleaned_oil.csv')
ppi_data_clean = pd.read_csv('cleaned_ppi.csv')
unemp_data_clean = pd.read_csv('cleaned_unemp.csv')
lcpi_data_clean = pd.read_csv('cleaned_lagged_cpi.csv')
cpi_data_clean = pd.read_csv('cleaned_cpi.csv')

# %%
oil_data_clean.drop(columns = ['ChangePercentYear', 'Value'], axis = 1, inplace = True)
ppi_data_clean.drop(columns = ['ChangePercentYear', 'Value'], axis = 1, inplace = True)
unemp_data_clean.drop(columns = ['ChangePercentYear', 'Value'], axis = 1, inplace = True)
lcpi_data_clean.drop(columns = ['ChangePercentYear', 'Value'], axis = 1, inplace = True)
cpi_data_clean.drop(columns = ['ChangePercentYear', 'Value'], axis = 1, inplace = True)

# %%
cpi_data_clean.fillna(method='bfill')
lcpi_data_clean.fillna(method='bfill')
oil_data_clean.fillna(method='bfill')
ppi_data_clean.fillna(method='bfill')
unemp_data_clean.fillna(method='bfill')
# Out:
# C:\Users\Suryanshu Choudhary\AppData\Local\Temp\ipykernel_17116\728974245.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   cpi_data_clean.fillna(method='bfill')
# C:\Users\Suryanshu Choudhary\AppData\Local\Temp\ipykernel_17116\728974245.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   lcpi_data_clean.fillna(method='bfill')
# C:\Users\Suryanshu Choudhary\AppData\Local\Temp\ipykernel_17116\728974245.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   oil_data_clean.fillna(method='bfill')
# C:\Users\Suryanshu Choudhary\AppData\Local\Temp\ipykernel_17116\728974245.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ppi_data_clean.fillna(method='bfill')
# C:\Users\Suryanshu Choudhary\AppData\Local\Temp\ipykernel_17116\728974245.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   unemp_data_clean.fillna(method='bfill')
#         Date  ChangePercentMonth
# 0    1948-01            0.175000
# 1    1948-02            0.175000
# 2    1948-03           -0.042553
# 3    1948-04           -0.111111
# 4    1948-05           -0.150000
# ..       ...                 ...
# 882  2021-07           -0.065574
# 883  2021-08           -0.070175
# 884  2021-09           -0.132075
# 885  2021-10           -0.065217
# 886  2021-11           -0.093023
#
# [887 rows x 2 columns]

# %%
oil_data_clean.columns = ['Date','Oil']
oil_data_clean.dropna(inplace = True)
ppi_data_clean.columns = ['Date','PPI']
ppi_data_clean.dropna(inplace = True)
unemp_data_clean.columns = ['Date','Unemployment']
unemp_data_clean.dropna(inplace = True)
lcpi_data_clean.columns = ['Date','LaggedCPI']
lcpi_data_clean.dropna(inplace = True)
cpi_data_clean.columns = ['Date','CPI']
cpi_data_clean.dropna(inplace = True)

dataframe_list = [cpi_data_clean, oil_data_clean, ppi_data_clean, unemp_data_clean, lcpi_data_clean]
# Join all datasets together
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Date'], how='inner'), dataframe_list)
df_merged.set_index('Date', inplace = True)

# %%
values = df_merged.values
# specify columns to plot
groups = [0, 1, 2, 3, 4]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(df_merged.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %%
# Data Preparation for LSTM Model
df_merged
# Out:
#               CPI       Oil       PPI  Unemployment  LaggedCPI
# Date
# 1983-04  0.007150  0.046464  0.000000     -0.074074   0.000000
# 1983-05  0.006085 -0.012406  0.003984     -0.020000   0.007150
# 1983-06  0.003024  0.037355  0.001984      0.040816   0.006085
# 1983-07  0.004020  0.019758  0.002970     -0.078431   0.003024
# 1983-08  0.003003 -0.012813  0.004936     -0.021277   0.004020
# ...           ...       ...       ...           ...        ...
# 2021-07  0.004811  0.006533  0.012888     -0.065574   0.009291
# 2021-08  0.002066 -0.073698  0.006750     -0.070175   0.004811
# 2021-09  0.002716  0.095328  0.009695     -0.132075   0.002066
# 2021-10  0.008308  0.089964  0.020312     -0.065217   0.002716
# 2021-11  0.004913 -0.194791  0.011736     -0.093023   0.008308
#
# [464 rows x 5 columns]

# %%
df_merged.isnull().sum()
# Out:
# CPI             0
# Oil             0
# PPI             0
# Unemployment    0
# LaggedCPI       0
# dtype: int64

# %%
# Splitting the dataset into train and test sets
df_train = df_merged.iloc[:357]
df_test = df_merged.iloc[357:]

# %%
# Use MinMaxScaler to normalise are values by scaling down values between a range of -1 to 1
# Instantiate scaler objects
x_scaler = MinMaxScaler(feature_range=(-1, 1))
y_scaler = MinMaxScaler(feature_range=(-1, 1))

x_train = x_scaler.fit_transform(df_train[['Oil','PPI','Unemployment','LaggedCPI']])
y_train = y_scaler.fit_transform(df_train[['CPI']])

x_test = x_scaler.transform(df_test[['Oil','PPI','Unemployment','LaggedCPI']])
y_test = y_scaler.transform(df_test[['CPI']])

# %%
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (357, 1, 4) (357, 1) (107, 1, 4) (107, 1)

# %%
# design network with 100 neurons
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(LSTM(200, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
# fit network
history = model.fit(x_train, y_train, epochs=152, batch_size=1, validation_data=(x_test, y_test), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# d:\Python\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/152
# 357/357 - 8s - 22ms/step - loss: 0.0294 - val_loss: 0.0213
# Epoch 2/152
# 357/357 - 2s - 6ms/step - loss: 0.0167 - val_loss: 0.0265
# Epoch 3/152
# 357/357 - 3s - 10ms/step - loss: 0.0165 - val_loss: 0.0346
# Epoch 4/152
# 357/357 - 2s - 6ms/step - loss: 0.0164 - val_loss: 0.0448
# Epoch 5/152
# 357/357 - 1s - 4ms/step - loss: 0.0163 - val_loss: 0.0566
# Epoch 6/152
# 357/357 - 2s - 4ms/step - loss: 0.0162 - val_loss: 0.0694
# Epoch 7/152
# 357/357 - 1s - 4ms/step - loss: 0.0161 - val_loss: 0.0831
# Epoch 8/152
# 357/357 - 2s - 7ms/step - loss: 0.0160 - val_loss: 0.0973
# Epoch 9/152
# 357/357 - 1s - 4ms/step - loss: 0.0159 - val_loss: 0.1120
# Epoch 10/152
# 357/357 - 1s - 4ms/step - loss: 0.0158 - val_loss: 0.1267
# Epoch 11/152
# 357/357 - 1s - 4ms/step - loss: 0.0157 - val_loss: 0.1411
# Epoch 12/152
# 357/357 - 1s - 4ms/step - loss: 0.0156 - val_loss: 0.1550
# Epoch 13/152
# 357/357 - 2s - 4ms/step - loss: 0.0155 - val_loss: 0.1680
# Epoch 14/152
# 357/357 - 1s - 4ms/step - loss: 0.0154 - val_loss: 0.1798
# Epoch 15/152
# 357/357 - 1s - 4ms/step - loss: 0.0154 - val_loss: 0.1902
# Epoch 16/152
# 357/357 - 3s - 8ms/step - loss: 0.0153 - val_loss: 0.1991
# Epoch 17/152
# 357/357 - 4s - 12ms/step - loss: 0.0152 - val_loss: 0.2066
# Epoch 18/152
# 357/357 - 5s - 13ms/step - loss: 0.0152 - val_loss: 0.2124
# Epoch 19/152
# 357/357 - 2s - 6ms/step - loss: 0.0151 - val_loss: 0.2171
# Epoch 20/152
# 357/357 - 2s - 5ms/step - loss: 0.0151 - val_loss: 0.2205
# Epoch 21/152
# 357/357 - 2s - 7ms/step - loss: 0.0150 - val_loss: 0.2229
# Epoch 22/152
# 357/357 - 2s - 5ms/step - loss: 0.0150 - val_loss: 0.2242
# Epoch 23/152
# 357/357 - 2s - 5ms/step - loss: 0.0150 - val_loss: 0.2252
# Epoch 24/152
# 357/357 - 2s - 5ms/step - loss: 0.0149 - val_loss: 0.2253
# Epoch 25/152
# 357/357 - 2s - 5ms/step - loss: 0.0149 - val_loss: 0.2251
# Epoch 26/152
# 357/357 - 2s - 5ms/step - loss: 0.0149 - val_loss: 0.2246
# Epoch 27/152
# 357/357 - 2s - 5ms/step - loss: 0.0148 - val_loss: 0.2237
# Epoch 28/152
# 357/357 - 2s - 6ms/step - loss: 0.0148 - val_loss: 0.2228
# Epoch 29/152
# 357/357 - 1s - 4ms/step - loss: 0.0148 - val_loss: 0.2214
# Epoch 30/152
# 357/357 - 1s - 4ms/step - loss: 0.0148 - val_loss: 0.2204
# Epoch 31/152
# 357/357 - 1s - 3ms/step - loss: 0.0148 - val_loss: 0.2189
# Epoch 32/152
# 357/357 - 2s - 5ms/step - loss: 0.0147 - val_loss: 0.2175
# Epoch 33/152
# 357/357 - 1s - 4ms/step - loss: 0.0147 - val_loss: 0.2160
# Epoch 34/152
# 357/357 - 2s - 5ms/step - loss: 0.0147 - val_loss: 0.2145
# Epoch 35/152
# 357/357 - 3s - 7ms/step - loss: 0.0147 - val_loss: 0.2130
# Epoch 36/152
# 357/357 - 4s - 10ms/step - loss: 0.0147 - val_loss: 0.2114
# Epoch 37/152
# 357/357 - 2s - 7ms/step - loss: 0.0147 - val_loss: 0.2098
# Epoch 38/152
# 357/357 - 4s - 11ms/step - loss: 0.0146 - val_loss: 0.2081
# Epoch 39/152
# 357/357 - 4s - 10ms/step - loss: 0.0146 - val_loss: 0.2064
# Epoch 40/152
# 357/357 - 2s - 5ms/step - loss: 0.0146 - val_loss: 0.2046
# Epoch 41/152
# 357/357 - 3s - 9ms/step - loss: 0.0146 - val_loss: 0.2028
# Epoch 42/152
# 357/357 - 2s - 5ms/step - loss: 0.0146 - val_loss: 0.2010
# Epoch 43/152
# 357/357 - 3s - 7ms/step - loss: 0.0146 - val_loss: 0.1992
# Epoch 44/152
# 357/357 - 2s - 5ms/step - loss: 0.0146 - val_loss: 0.1972
# Epoch 45/152
# 357/357 - 1s - 4ms/step - loss: 0.0145 - val_loss: 0.1953
# Epoch 46/152
# 357/357 - 3s - 8ms/step - loss: 0.0145 - val_loss: 0.1934
# Epoch 47/152
# 357/357 - 3s - 8ms/step - loss: 0.0145 - val_loss: 0.1915
# Epoch 48/152
# 357/357 - 3s - 7ms/step - loss: 0.0145 - val_loss: 0.1894
# Epoch 49/152
# 357/357 - 2s - 6ms/step - loss: 0.0145 - val_loss: 0.1874
# Epoch 50/152
# 357/357 - 2s - 5ms/step - loss: 0.0145 - val_loss: 0.1853
# Epoch 51/152
# 357/357 - 3s - 8ms/step - loss: 0.0145 - val_loss: 0.1832
# Epoch 52/152
# 357/357 - 1s - 4ms/step - loss: 0.0144 - val_loss: 0.1810
# Epoch 53/152
# 357/357 - 2s - 7ms/step - loss: 0.0144 - val_loss: 0.1787
# Epoch 54/152
# 357/357 - 2s - 5ms/step - loss: 0.0144 - val_loss: 0.1766
# Epoch 55/152
# 357/357 - 2s - 5ms/step - loss: 0.0144 - val_loss: 0.1744
# Epoch 56/152
# 357/357 - 1s - 4ms/step - loss: 0.0144 - val_loss: 0.1720
# Epoch 57/152
# 357/357 - 1s - 4ms/step - loss: 0.0144 - val_loss: 0.1699
# Epoch 58/152
# 357/357 - 1s - 4ms/step - loss: 0.0144 - val_loss: 0.1675
# Epoch 59/152
# 357/357 - 1s - 4ms/step - loss: 0.0144 - val_loss: 0.1652
# Epoch 60/152
# 357/357 - 1s - 4ms/step - loss: 0.0143 - val_loss: 0.1629
# Epoch 61/152
# 357/357 - 1s - 4ms/step - loss: 0.0143 - val_loss: 0.1605
# Epoch 62/152
# 357/357 - 2s - 5ms/step - loss: 0.0143 - val_loss: 0.1580
# Epoch 63/152
# 357/357 - 2s - 5ms/step - loss: 0.0143 - val_loss: 0.1557
# Epoch 64/152
# 357/357 - 3s - 8ms/step - loss: 0.0143 - val_loss: 0.1531
# Epoch 65/152
# 357/357 - 3s - 8ms/step - loss: 0.0143 - val_loss: 0.1506
# Epoch 66/152
# 357/357 - 2s - 6ms/step - loss: 0.0143 - val_loss: 0.1482
# Epoch 67/152
# 357/357 - 2s - 6ms/step - loss: 0.0143 - val_loss: 0.1457
# Epoch 68/152
# 357/357 - 2s - 7ms/step - loss: 0.0143 - val_loss: 0.1431
# Epoch 69/152
# 357/357 - 2s - 5ms/step - loss: 0.0143 - val_loss: 0.1406
# Epoch 70/152
# 357/357 - 2s - 7ms/step - loss: 0.0142 - val_loss: 0.1380
# Epoch 71/152
# 357/357 - 2s - 5ms/step - loss: 0.0142 - val_loss: 0.1355
# Epoch 72/152
# 357/357 - 2s - 5ms/step - loss: 0.0142 - val_loss: 0.1329
# Epoch 73/152
# 357/357 - 2s - 5ms/step - loss: 0.0142 - val_loss: 0.1303
# Epoch 74/152
# 357/357 - 2s - 5ms/step - loss: 0.0142 - val_loss: 0.1278
# Epoch 75/152
# 357/357 - 2s - 6ms/step - loss: 0.0142 - val_loss: 0.1252
# Epoch 76/152
# 357/357 - 3s - 8ms/step - loss: 0.0142 - val_loss: 0.1227
# Epoch 77/152
# 357/357 - 2s - 6ms/step - loss: 0.0142 - val_loss: 0.1201
# Epoch 78/152
# 357/357 - 3s - 7ms/step - loss: 0.0142 - val_loss: 0.1176
# Epoch 79/152
# 357/357 - 3s - 8ms/step - loss: 0.0142 - val_loss: 0.1151
# Epoch 80/152
# 357/357 - 2s - 7ms/step - loss: 0.0141 - val_loss: 0.1126
# Epoch 81/152
# 357/357 - 3s - 7ms/step - loss: 0.0141 - val_loss: 0.1101
# Epoch 82/152
# 357/357 - 3s - 8ms/step - loss: 0.0141 - val_loss: 0.1077
# Epoch 83/152
# 357/357 - 2s - 6ms/step - loss: 0.0141 - val_loss: 0.1053
# Epoch 84/152
# 357/357 - 2s - 6ms/step - loss: 0.0141 - val_loss: 0.1029
# Epoch 85/152
# 357/357 - 2s - 6ms/step - loss: 0.0141 - val_loss: 0.1006
# Epoch 86/152
# 357/357 - 2s - 6ms/step - loss: 0.0141 - val_loss: 0.0984
# Epoch 87/152
# 357/357 - 2s - 7ms/step - loss: 0.0141 - val_loss: 0.0961
# Epoch 88/152
# 357/357 - 2s - 6ms/step - loss: 0.0141 - val_loss: 0.0939
# Epoch 89/152
# 357/357 - 2s - 6ms/step - loss: 0.0141 - val_loss: 0.0917
# Epoch 90/152
# 357/357 - 3s - 7ms/step - loss: 0.0141 - val_loss: 0.0896
# Epoch 91/152
# 357/357 - 3s - 8ms/step - loss: 0.0141 - val_loss: 0.0875
# Epoch 92/152
# 357/357 - 2s - 6ms/step - loss: 0.0140 - val_loss: 0.0855
# Epoch 93/152
# 357/357 - 2s - 6ms/step - loss: 0.0140 - val_loss: 0.0836
# Epoch 94/152
# 357/357 - 2s - 6ms/step - loss: 0.0140 - val_loss: 0.0815
# Epoch 95/152
# 357/357 - 2s - 5ms/step - loss: 0.0140 - val_loss: 0.0796
# Epoch 96/152
# 357/357 - 3s - 8ms/step - loss: 0.0140 - val_loss: 0.0776
# Epoch 97/152
# 357/357 - 2s - 5ms/step - loss: 0.0140 - val_loss: 0.0757
# Epoch 98/152
# 357/357 - 3s - 7ms/step - loss: 0.0140 - val_loss: 0.0739
# Epoch 99/152
# 357/357 - 3s - 7ms/step - loss: 0.0140 - val_loss: 0.0722
# Epoch 100/152
# 357/357 - 2s - 5ms/step - loss: 0.0140 - val_loss: 0.0703
# Epoch 101/152
# 357/357 - 2s - 5ms/step - loss: 0.0140 - val_loss: 0.0685
# Epoch 102/152
# 357/357 - 3s - 8ms/step - loss: 0.0140 - val_loss: 0.0667
# Epoch 103/152
# 357/357 - 3s - 9ms/step - loss: 0.0139 - val_loss: 0.0651
# Epoch 104/152
# 357/357 - 4s - 12ms/step - loss: 0.0139 - val_loss: 0.0633
# Epoch 105/152
# 357/357 - 2s - 6ms/step - loss: 0.0139 - val_loss: 0.0616
# Epoch 106/152
# 357/357 - 2s - 7ms/step - loss: 0.0139 - val_loss: 0.0600
# Epoch 107/152
# 357/357 - 3s - 7ms/step - loss: 0.0139 - val_loss: 0.0583
# Epoch 108/152
# 357/357 - 2s - 7ms/step - loss: 0.0139 - val_loss: 0.0566
# Epoch 109/152
# 357/357 - 3s - 8ms/step - loss: 0.0139 - val_loss: 0.0550
# Epoch 110/152
# 357/357 - 3s - 8ms/step - loss: 0.0139 - val_loss: 0.0534
# Epoch 111/152
# 357/357 - 3s - 7ms/step - loss: 0.0139 - val_loss: 0.0517
# Epoch 112/152
# 357/357 - 2s - 5ms/step - loss: 0.0139 - val_loss: 0.0501
# Epoch 113/152
# 357/357 - 2s - 5ms/step - loss: 0.0139 - val_loss: 0.0486
# Epoch 114/152
# 357/357 - 2s - 7ms/step - loss: 0.0138 - val_loss: 0.0470
# Epoch 115/152
# 357/357 - 3s - 8ms/step - loss: 0.0138 - val_loss: 0.0455
# Epoch 116/152
# 357/357 - 3s - 8ms/step - loss: 0.0138 - val_loss: 0.0440
# Epoch 117/152
# 357/357 - 2s - 6ms/step - loss: 0.0138 - val_loss: 0.0425
# Epoch 118/152
# 357/357 - 3s - 9ms/step - loss: 0.0138 - val_loss: 0.0411
# Epoch 119/152
# 357/357 - 2s - 6ms/step - loss: 0.0138 - val_loss: 0.0396
# Epoch 120/152
# 357/357 - 2s - 6ms/step - loss: 0.0138 - val_loss: 0.0382
# Epoch 121/152
# 357/357 - 2s - 5ms/step - loss: 0.0138 - val_loss: 0.0368
# Epoch 122/152
# 357/357 - 2s - 6ms/step - loss: 0.0138 - val_loss: 0.0354
# Epoch 123/152
# 357/357 - 3s - 7ms/step - loss: 0.0138 - val_loss: 0.0340
# Epoch 124/152
# 357/357 - 2s - 5ms/step - loss: 0.0137 - val_loss: 0.0327
# Epoch 125/152
# 357/357 - 2s - 6ms/step - loss: 0.0137 - val_loss: 0.0314
# Epoch 126/152
# 357/357 - 2s - 4ms/step - loss: 0.0137 - val_loss: 0.0301
# Epoch 127/152
# 357/357 - 2s - 5ms/step - loss: 0.0137 - val_loss: 0.0288
# Epoch 128/152
# 357/357 - 3s - 7ms/step - loss: 0.0137 - val_loss: 0.0276
# Epoch 129/152
# 357/357 - 2s - 6ms/step - loss: 0.0137 - val_loss: 0.0264
# Epoch 130/152
# 357/357 - 3s - 9ms/step - loss: 0.0137 - val_loss: 0.0253
# Epoch 131/152
# 357/357 - 2s - 7ms/step - loss: 0.0137 - val_loss: 0.0242
# Epoch 132/152
# 357/357 - 2s - 6ms/step - loss: 0.0137 - val_loss: 0.0231
# Epoch 133/152
# 357/357 - 2s - 6ms/step - loss: 0.0137 - val_loss: 0.0222
# Epoch 134/152
# 357/357 - 2s - 6ms/step - loss: 0.0136 - val_loss: 0.0212
# Epoch 135/152
# 357/357 - 3s - 7ms/step - loss: 0.0136 - val_loss: 0.0203
# Epoch 136/152
# 357/357 - 2s - 5ms/step - loss: 0.0136 - val_loss: 0.0194
# Epoch 137/152
# 357/357 - 2s - 4ms/step - loss: 0.0136 - val_loss: 0.0187
# Epoch 138/152
# 357/357 - 3s - 8ms/step - loss: 0.0136 - val_loss: 0.0180
# Epoch 139/152
# 357/357 - 2s - 4ms/step - loss: 0.0136 - val_loss: 0.0173
# Epoch 140/152
# 357/357 - 2s - 7ms/step - loss: 0.0136 - val_loss: 0.0167
# Epoch 141/152
# 357/357 - 1s - 4ms/step - loss: 0.0136 - val_loss: 0.0162
# Epoch 142/152
# 357/357 - 3s - 9ms/step - loss: 0.0136 - val_loss: 0.0157
# Epoch 143/152
# 357/357 - 3s - 7ms/step - loss: 0.0136 - val_loss: 0.0153
# Epoch 144/152
# 357/357 - 3s - 8ms/step - loss: 0.0135 - val_loss: 0.0149
# Epoch 145/152
# 357/357 - 2s - 5ms/step - loss: 0.0135 - val_loss: 0.0146
# Epoch 146/152
# 357/357 - 2s - 7ms/step - loss: 0.0135 - val_loss: 0.0144
# Epoch 147/152
# 357/357 - 3s - 7ms/step - loss: 0.0135 - val_loss: 0.0142
# Epoch 148/152
# 357/357 - 1s - 4ms/step - loss: 0.0135 - val_loss: 0.0140
# Epoch 149/152
# 357/357 - 2s - 6ms/step - loss: 0.0135 - val_loss: 0.0140
# Epoch 150/152
# 357/357 - 2s - 6ms/step - loss: 0.0135 - val_loss: 0.0138
# Epoch 151/152
# 357/357 - 2s - 5ms/step - loss: 0.0135 - val_loss: 0.0140
# Epoch 152/152
# 357/357 - 1s - 4ms/step - loss: 0.0135 - val_loss: 0.0139

# %%
## Testing the Model
from sklearn.metrics import mean_absolute_error, r2_score
# make a prediction
yhat = model.predict(x_test)
# invert scaling for our forecast
inv_yhat = y_scaler.inverse_transform(yhat)
# Add our forecast to the test dataframe and plot the results
df_test['Predicted CPI'] = inv_yhat
df_test[['CPI','Predicted CPI']].plot(figsize=(14,5))
# Calculate RMSE
multi_rmse = sqrt(mean_squared_error(df_test['CPI'], df_test['Predicted CPI']))
print('Test RMSE:', multi_rmse)
# Calculate MAE
multi_mae = mean_absolute_error(df_test['CPI'], df_test['Predicted CPI'])
print('Test MAE:', multi_mae)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# C:\Users\Suryanshu Choudhary\AppData\Local\Temp\ipykernel_17116\3692853901.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Predicted CPI'] = inv_yhat
# Test RMSE: 0.0018518580116572362
# Test MAE: 0.0014281404151181673

# %%
df_test
# Out:
#               CPI       Oil       PPI  Unemployment  LaggedCPI  Predicted CPI
# Date
# 2013-01  0.002957  0.061751  0.004963      0.118421  -0.002693       0.001726
# 2013-02  0.008190 -0.055801  0.008889     -0.047059   0.002957       0.003368
# 2013-03  0.002615  0.056274 -0.001468     -0.061728   0.008190       0.003310
# 2013-04 -0.001040 -0.038774 -0.002451     -0.065789   0.002615       0.001519
# 2013-05  0.001780 -0.015943  0.002948      0.028169  -0.001040       0.000622
# ...           ...       ...       ...           ...        ...            ...
# 2021-07  0.004811  0.006533  0.012888     -0.065574   0.009291       0.005521
# 2021-08  0.002066 -0.073698  0.006750     -0.070175   0.004811       0.003498
# 2021-09  0.002716  0.095328  0.009695     -0.132075   0.002066       0.004946
# 2021-10  0.008308  0.089964  0.020312     -0.065217   0.002716       0.006515
# 2021-11  0.004913 -0.194791  0.011736     -0.093023   0.008308       0.003971
#
# [107 rows x 6 columns]

# %%
print('Multivariate Long Short Memory Network RMSE:' , multi_rmse)
print('Multivariate Long Short Memory Network MAE:' , multi_mae)
# Out:
# Multivariate Long Short Memory Network RMSE: 0.0018518580116572362
# Multivariate Long Short Memory Network MAE: 0.0014281404151181673

# %%
model.save('multivariate.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
